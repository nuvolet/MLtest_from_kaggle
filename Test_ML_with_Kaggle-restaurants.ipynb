# %% [markdown]
# # Restaurant Data with Consumer Ratings

# %%
import mlcroissant as mlc
import pandas as pd

# Fetch the Croissant JSON-LD
croissant_dataset = mlc.Dataset('https://www.kaggle.com/datasets/uciml/restaurant-data-with-consumer-ratings/croissant/download')

# Check what record sets are in the dataset
record_sets = croissant_dataset.metadata.record_sets
print(record_sets)

# Fetch the records and put them in a DataFrame
record_set_df = pd.DataFrame(croissant_dataset.records(record_set=record_sets[0].uuid))
record_set_df.head()
# Out:
# WARNING:absl:WARNING: The JSON-LD `@context` is not standard. Refer to the official @context (e.g., from the example datasets in https://github.com/mlcommons/croissant/tree/main/datasets/1.0). The different keys are: {'samplingRate', 'isLiveDataset', 'rai', 'examples'}
# WARNING:absl:Found the following 1 warning(s) during the validation:
#   -  [Metadata(Restaurant Data with Consumer Ratings)] Property "http://mlcommons.org/croissant/citeAs" is recommended, but does not exist.
# [RecordSet(uuid="chefmozaccepts.csv"), RecordSet(uuid="chefmozcuisine.csv"), RecordSet(uuid="chefmozhours4.csv"), RecordSet(uuid="chefmozparking.csv"), RecordSet(uuid="geoplaces2.csv"), RecordSet(uuid="rating_final.csv"), RecordSet(uuid="usercuisine.csv"), RecordSet(uuid="userpayment.csv"), RecordSet(uuid="userprofile.csv")]
# ...
#   chefmozaccepts.csv/placeID chefmozaccepts.csv/Rpayment
# 0                  b'135110'                     b'cash'
# 1                  b'135110'                     b'VISA'
# ...

# %%
print(record_sets)
# Out:
# [RecordSet(uuid="chefmozaccepts.csv"), RecordSet(uuid="chefmozcuisine.csv"), RecordSet(uuid="chefmozhours4.csv"), RecordSet(uuid="chefmozparking.csv"), RecordSet(uuid="geoplaces2.csv"), RecordSet(uuid="rating_final.csv"), RecordSet(uuid="usercuisine.csv"), RecordSet(uuid="userpayment.csv"), RecordSet(uuid="userprofile.csv")]

# %%
record_set_df = pd.DataFrame(croissant_dataset.records(record_set=record_sets[1].uuid))
record_set_df.head()
# Out:
#   chefmozcuisine.csv/placeID chefmozcuisine.csv/Rcuisine
# 0                  b'135110'                  b'Spanish'
# 1                  b'135109'                  b'Italian'
# 2                  b'135107'           b'Latin_American'
# 3                  b'135106'                  b'Mexican'
# 4                  b'135105'                b'Fast_Food'

# %%
record_set_df = pd.DataFrame(croissant_dataset.records(record_set=record_sets[4].uuid))
record_set_df.head()
# Out:
#   geoplaces2.csv/placeID geoplaces2.csv/latitude geoplaces2.csv/longitude  \
# 0              b'134999'            b'18.915421'            b'-99.184871'
# 1              b'132825'           b'22.1473922'           b'-100.983092'
# 2              b'135106'           b'22.1497088'          b'-100.9760928'
# 3              b'132667'           b'23.7526973'           b'-99.1633594'
# 4              b'132613'           b'23.7529035'            b'-99.165076'
#
#                        geoplaces2.csv/the_geom_meter  \
# 0  b'0101000020957F000088568DE356715AC138C0A525FC...
# 1  b'0101000020957F00001AD016568C4858C1243261274B...
# 2  b'0101000020957F0000649D6F21634858C119AE9BF528...
# 3  b'0101000020957F00005D67BCDDED8157C1222A2DC8D8...
# 4  b'0101000020957F00008EBA2D06DC8157C194E03B7B50...
#
#                         geoplaces2.csv/name  \
# 0                        b'Kiku Cuernavaca'
# 1                        b'puesto de tacos'
# 2  b'El Rinc\xef\xbf\xbdn de San Francisco'
# ...

# %%
import mlcroissant as mlc
import pandas as pd

# Fetch the Croissant JSON-LD
croissant_dataset = mlc.Dataset('https://www.kaggle.com/datasets/divyaraj2006/social-media-engagement/croissant/download')

# Check what record sets are in the dataset
record_sets = croissant_dataset.metadata.record_sets
print(record_sets)

# Fetch the records and put them in a DataFrame
record_set_df = pd.DataFrame(croissant_dataset.records(record_set=record_sets[0].uuid))
record_set_df.head()
# Out:
# WARNING:absl:WARNING: The JSON-LD `@context` is not standard. Refer to the official @context (e.g., from the example datasets in https://github.com/mlcommons/croissant/tree/main/datasets/1.0). The different keys are: {'samplingRate', 'rai', 'examples'}
# WARNING:absl:Found the following 1 warning(s) during the validation:
#   -  [Metadata(social media engagement)] Property "http://mlcommons.org/croissant/citeAs" is recommended, but does not exist.
# [RecordSet(uuid="social_media_engagement1.csv")]
# ...
#   social_media_engagement1.csv/post_id social_media_engagement1.csv/platform  \
# 0                                 b'1'                           b'Facebook'
# 1                                 b'2'                           b'Facebook'
# 2                                 b'3'                          b'Instagram'
# 3                                 b'4'                            b'Twitter'
# 4                                 b'5'                            b'Twitter'
#
# ...

# %%
record_set_df.size
# Out:
# 900
